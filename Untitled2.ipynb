# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils import class_weight
from imblearn.over_sampling import RandomOverSampler

# %%
# 1. Load dan Preprocess Data
print("=== LANGKAH 1: LOAD DAN PREPROCESS DATA ===")
df = pd.read_csv("global_financial_id.csv")

# Filter data
columns_to_check = ['Year', 'GDP_Growth', 'Inflation_Rate', 'M2_Money_Supply', 'Government_Debt', 'Recession']
df = df.dropna(subset=columns_to_check)
print("\n5 data pertama:")
df.head()
# Out:
# === LANGKAH 1: LOAD DAN PREPROCESS DATA ===
#
# 5 data pertama:
#     Year  GDP_Growth  Inflation_Rate  M2_Money_Supply  Government_Debt  \
# 8   1966    4731.888           31.88            462.0         320999.0
# 9   1967    4870.299           32.90            481.6         330947.0
# 10  1968    5057.553           34.10            527.4         349473.0
# 11  1969    5283.597           35.70            569.3         359546.0
# 12  1970    5300.652           37.90            589.6         372007.0
#
#     Recession
# 8           0
# 9           0
# 10          0
# 11          0
# 12          1

# %%
# 2. Analisis Data
print("\n=== LANGKAH 2: ANALISIS DATA ===")
plt.figure(figsize=(15, 10))

# Distribusi Recession
plt.subplot(2, 2, 1)
sns.countplot(x='Recession', data=df)
plt.title('Distribusi Recession (0=Tidak Resesi, 1=Resesi)')

# GDP Growth vs Recession
plt.subplot(2, 2, 2)
sns.boxplot(x='Recession', y='GDP_Growth', data=df)
plt.title('GDP Growth vs Recession')

# Korelasi antar fitur
plt.subplot(2, 2, 3)
corr_matrix = df[['GDP_Growth', 'Inflation_Rate', 'M2_Money_Supply', 'Government_Debt', 'Recession']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Korelasi Antar Fitur')

plt.tight_layout()
plt.show()
# Out:
# === LANGKAH 2: ANALISIS DATA ===

# %%
# 3. Penanganan Class Imbalance
print("\n=== LANGKAH 3: PENANGANAN CLASS IMBALANCE ===")
print("Distribusi Kelas Awal (Recession):")
print(df['Recession'].value_counts())

features = ['GDP_Growth', 'Inflation_Rate', 'M2_Money_Supply', 'Government_Debt']
X = df[features].values
y = df['Recession'].values  # Menggunakan kolom Recession sebagai target

# Oversampling jika kelas minoritas < 20%
if df['Recession'].mean() < 0.2:
    ros = RandomOverSampler(random_state=42)
    X_res, y_res = ros.fit_resample(X, y)
    print("\nSetelah Oversampling:")
    print(pd.Series(y_res).value_counts())
else:
    X_res, y_res = X, y
# Out:
# === LANGKAH 3: PENANGANAN CLASS IMBALANCE ===
# Distribusi Kelas Awal (Recession):
# Recession
# 0    51
# 1     8
# Name: count, dtype: int64
#
# Setelah Oversampling:
# 0    51
# 1    51
# Name: count, dtype: int64

# %%
# 4. Preprocessing Data
print("\n=== LANGKAH 4: PREPROCESSING DATA ===")
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_res)

# Membuat sequences dengan time steps
time_steps = 3
X_sequences = []
y_sequences = []

for i in range(time_steps, len(X_scaled)):
    X_sequences.append(X_scaled[i-time_steps:i])
    y_sequences.append(y_res[i])

X_sequences = np.array(X_sequences)
y_sequences = np.array(y_sequences)
# Out:
# === LANGKAH 4: PREPROCESSING DATA ===

# %%
# 5. Split Data
print("\n=== LANGKAH 5: SPLIT DATA ===")
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_sequences, 
                                                   test_size=0.2, 
                                                   random_state=42,
                                                   shuffle=True)
# Out:
# === LANGKAH 5: SPLIT DATA ===

# %%
# 6. Bangun Model RNN
print("\n=== LANGKAH 6: MEMBANGUN MODEL RNN ===")
model = Sequential([
    SimpleRNN(128, input_shape=(X_train.shape[1], X_train.shape[2]), 
               return_sequences=True, activation='tanh'),
    Dropout(0.3),
    SimpleRNN(64, activation='tanh'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, 
              loss='binary_crossentropy', 
              metrics=['accuracy', 
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.Recall(name='recall')])

model.summary()
# Out:
# === LANGKAH 6: MEMBANGUN MODEL RNN ===
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 3, 128)         │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 64)             │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,489 (123.00 KB)
#  Trainable params: 31,489 (123.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 7. Training Model
print("\n=== LANGKAH 7: TRAINING MODEL ===")
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# === LANGKAH 7: TRAINING MODEL ===
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - accuracy: 0.5159 - loss: 0.6906 - precision: 0.5085 - recall: 0.6801 - val_accuracy: 0.4375 - val_loss: 0.7147 - val_precision: 1.0000 - val_recall: 0.1818
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5789 - loss: 0.6758 - precision: 0.5385 - recall: 0.4892 - val_accuracy: 0.3750 - val_loss: 0.7233 - val_precision: 1.0000 - val_recall: 0.0909
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6103 - loss: 0.6702 - precision: 0.6270 - recall: 0.4796 - val_accuracy: 0.3750 - val_loss: 0.7211 - val_precision: 0.6667 - val_recall: 0.1818
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5790 - loss: 0.6766 - precision: 0.6093 - recall: 0.5108 - val_accuracy: 0.5000 - val_loss: 0.7034 - val_precision: 0.8000 - val_recall: 0.3636
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5999 - loss: 0.6662 - precision: 0.6280 - recall: 0.4677 - val_accuracy: 0.5000 - val_loss: 0.6988 - val_precision: 0.8000 - val_recall: 0.3636
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5159 - loss: 0.6652 - precision: 0.4937 - recall: 0.4247 - val_accuracy: 0.5000 - val_loss: 0.7038 - val_precision: 0.8000 - val_recall: 0.3636
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6215 - loss: 0.6524 - precision: 0.7917 - recall: 0.3848 - val_accuracy: 0.5625 - val_loss: 0.7040 - val_precision: 0.8333 - val_recall: 0.4545
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5898 - loss: 0.6635 - precision: 0.6373 - recall: 0.3692 - val_accuracy: 0.5000 - val_loss: 0.7075 - val_precision: 0.8000 - val_recall: 0.3636
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6738 - loss: 0.6183 - precision: 0.8347 - recall: 0.4261 - val_accuracy: 0.5625 - val_loss: 0.6899 - val_precision: 0.8333 - val_recall: 0.4545
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7475 - loss: 0.5826 - precision: 0.9091 - recall: 0.5655 - val_accuracy: 0.6250 - val_loss: 0.6661 - val_precision: 0.8571 - val_recall: 0.5455
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7474 - loss: 0.6024 - precision: 0.8677 - recall: 0.5649 - val_accuracy: 0.6250 - val_loss: 0.6469 - val_precision: 0.8571 - val_recall: 0.5455
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7576 - loss: 0.5704 - precision: 0.8394 - recall: 0.5964 - val_accuracy: 0.6250 - val_loss: 0.6294 - val_precision: 0.8571 - val_recall: 0.5455
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6946 - loss: 0.5982 - precision: 0.6834 - recall: 0.6394 - val_accuracy: 0.6250 - val_loss: 0.6160 - val_precision: 0.8571 - val_recall: 0.5455
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7998 - loss: 0.5357 - precision: 0.8908 - recall: 0.6894 - val_accuracy: 0.6250 - val_loss: 0.5897 - val_precision: 0.8571 - val_recall: 0.5455
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7474 - loss: 0.5334 - precision: 0.8410 - recall: 0.6406 - val_accuracy: 0.6875 - val_loss: 0.5605 - val_precision: 0.8750 - val_recall: 0.6364
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.
- val_precision: 1.0000 - val_recall: 0.7273
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9158 - loss: 0.2963 - precision: 1.0000 - recall: 0.8156 - val_accuracy: 0.8125 - val_loss: 0.4676 - val_precision: 1.0000 - val_recall: 0.7273
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9054 - loss: 0.2400 - precision: 0.9540 - recall: 0.8552 - val_accuracy: 0.8125 - val_loss: 0.4956 - val_precision: 1.0000 - val_recall: 0.7273

# %%
# 8. Evaluasi Model
print("\n=== LANGKAH 8: EVALUASI MODEL ===")
# Plot akurasi dan loss
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.tight_layout()
plt.show()

# Prediksi dan Confusion Matrix
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['No Recession', 'Recession'],
            yticklabels=['No Recession', 'Recession'])
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['No Recession', 'Recession']))
# Out:
# === LANGKAH 8: EVALUASI MODEL ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
# No Recession       0.85      1.00      0.92        11
#    Recession       1.00      0.78      0.88         9
#
#     accuracy                           0.90        20
#    macro avg       0.92      0.89      0.90        20
# weighted avg       0.92      0.90      0.90        20

# %%
# 9. Prediksi 30 Tahun ke Depan
print("\n=== LANGKAH 9: PREDIKSI 30 TAHUN KE DEPAN ===")
last_year = df['Year'].max()
future_years = range(last_year + 1, last_year + 31)

# Gunakan data terakhir sebagai seed
current_sequence = X_scaled[-time_steps:].reshape(1, time_steps, len(features))

predictions = []
recession_probs = []

for year in future_years:
    # Prediksi probabilitas resesi
    recession_prob = model.predict(current_sequence, verbose=0)[0][0]
    recession_probs.append(recession_prob)
    
    # Prediksi fitur untuk tahun berikutnya (sederhana)
    last_features = current_sequence[0, -1, :].copy()
    
    # Simulasi perubahan fitur
    last_features[0] = np.clip(last_features[0] + np.random.normal(0, 0.03), 0, 1)  # GDP
    last_features[1] = np.clip(last_features[1] + np.random.normal(0, 0.05), 0, 1)  # Inflasi
    last_features[2] = np.clip(last_features[2] + np.random.normal(0.02, 0.03), 0, 1)  # Money Supply
    last_features[3] = np.clip(last_features[3] + np.random.normal(0.03, 0.02), 0, 1)  # Debt
    
    # Update sequence
    new_sequence = np.append(current_sequence[0, 1:, :], [last_features], axis=0)
    current_sequence = new_sequence.reshape(1, time_steps, len(features))
    
    predictions.append(last_features)

predictions = np.array(predictions)

# Konversi ke nilai asli
predicted_values = scaler.inverse_transform(predictions)
recession_years = [year for year, prob in zip(future_years, recession_probs) if prob > 0.5]
# Out:
# === LANGKAH 9: PREDIKSI 30 TAHUN KE DEPAN ===

# %%
# 10. Visualisasi Prediksi
print("\n=== LANGKAH 10: VISUALISASI PREDIKSI ===")
plt.figure(figsize=(14, 7))

# Plot data historis
plt.plot(df['Year'], df['GDP_Growth'], 'b-', label='Data Historis', linewidth=2)
# Tandai resesi historis
recession_data = df[df['Recession'] == 1]
plt.scatter(recession_data['Year'], recession_data['GDP_Growth'], 
           color='blue', s=100, label='Resesi Historis', marker='x')

# Plot prediksi
plt.plot(future_years, predicted_values[:, 0], 'r--', label='Prediksi', linewidth=2)
# Tandai prediksi resesi
if recession_years:
    recession_indices = [list(future_years).index(year) for year in recession_years]
    plt.scatter(recession_years, [predicted_values[i, 0] for i in recession_indices],
               color='red', s=100, label='Prediksi Resesi', marker='x')

plt.title('Prediksi Resesi 30 Tahun ke Depan', fontsize=16)
plt.xlabel('Tahun', fontsize=14)
plt.ylabel('GDP Growth (%)', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Format x-axis
all_years = list(df['Year']) + list(future_years)
plt.xticks(np.arange(min(all_years), max(all_years)+1, 5), rotation=45)

plt.tight_layout()
plt.show()
# Out:
# === LANGKAH 10: VISUALISASI PREDIKSI ===

# %%
# 11. Hasil Prediksi
print("\n=== HASIL PREDIKSI RESESI 30 TAHUN KE DEPAN ===")
if recession_years:
    print("Tahun-tahun prediksi resesi:")
    for year in recession_years:
        idx = list(future_years).index(year)
        print(f"- {year}: Probabilitas Resesi = {recession_probs[idx]:.2%}, GDP Growth Prediksi = {predicted_values[idx, 0]:.2f}%")
else:
    print("Tidak ada prediksi resesi dalam 30 tahun ke depan")
# Out:
# === HASIL PREDIKSI RESESI 30 TAHUN KE DEPAN ===
# Tahun-tahun prediksi resesi:
# - 2025: Probabilitas Resesi = 99.37%, GDP Growth Prediksi = 5488.08%
# - 2026: Probabilitas Resesi = 99.68%, GDP Growth Prediksi = 6189.36%
# - 2027: Probabilitas Resesi = 57.18%, GDP Growth Prediksi = 5923.36%
# - 2028: Probabilitas Resesi = 52.81%, GDP Growth Prediksi = 5234.51%
# - 2029: Probabilitas Resesi = 53.47%, GDP Growth Prediksi = 4763.90%
# - 2030: Probabilitas Resesi = 56.30%, GDP Growth Prediksi = 4731.89%
# - 2031: Probabilitas Resesi = 88.38%, GDP Growth Prediksi = 4731.89%
# - 2032: Probabilitas Resesi = 72.42%, GDP Growth Prediksi = 4731.89%
# - 2033: Probabilitas Resesi = 80.04%, GDP Growth Prediksi = 5303.19%
# - 2034: Probabilitas Resesi = 92.94%, GDP Growth Prediksi = 5169.07%
# - 2035: Probabilitas Resesi = 91.22%, GDP Growth Prediksi = 4991.94%
# - 2036: Probabilitas Resesi = 91.51%, GDP Growth Prediksi = 4731.89%
# - 2037: Probabilitas Resesi = 93.08%, GDP Growth Prediksi = 4731.89%
# - 2038: Probabilitas Resesi = 95.78%, GDP Growth Prediksi = 4731.89%
# - 2039: Probabilitas Resesi = 97.47%, GDP Growth Prediksi = 4731.89%
# - 2040: Probabilitas Resesi = 97.30%, GDP Growth Prediksi = 4731.89%
# - 2041: Probabilitas Resesi = 98.75%, GDP Growth Prediksi = 6328.61%
# - 2042: Probabilitas Resesi = 98.60%, GDP Growth Prediksi = 6229.15%
# - 2043: Probabilitas Resesi = 98.06%, GDP Growth Prediksi = 6177.05%
# - 2044: Probabilitas Resesi = 97.99%, GDP Growth Prediksi = 6397.02%
# - 2045: Probabilitas Resesi = 97.60%, GDP Growth Prediksi = 4962.06%
# - 2046: Probabilitas Resesi = 98.75%, GDP Growth Prediksi = 4877.07%
# - 2047: Probabilitas Resesi = 99.27%, GDP Growth Prediksi = 5399.77%
# - 2048: Probabilitas Resesi = 99.18%, GDP Growth Prediksi = 4731.89%
# - 2049: Probabilitas Resesi = 98.84%, GDP Growth Prediksi = 5442.24%
# - 2050: Probabilitas Resesi = 99.29%, GDP Growth Prediksi = 5343.31%
# - 2051: Probabilitas Resesi = 98.32%, GDP Growth Prediksi = 5396.06%
# - 2052: Probabilitas Resesi = 98.83%, GDP Growth Prediksi = 5612.77%
# - 2053: Probabilitas Resesi = 99.12%, GDP Growth Prediksi = 5710.61%
# - 2054: Probabilitas Resesi = 99.31%, GDP Growth Prediksi = 5945.52%
